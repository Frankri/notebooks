# %% [markdown]
# ##Preparations
# import the librarys pandas, numpy, matplotlib and seaborn; do some 'magic' commands pdb for debugging and pylab inline for showing the graphs inline

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib as plt

# %%
import seaborn as sns

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['plt']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %% [markdown]
# ## Start Work
# read in the data as DataFrame

# %%
data = pd.read_csv('Downloads/turnstile_data_master_with_weather.csv')

# %%
data.describe()
# Out:
#           Unnamed: 0           Hour  ENTRIESn_hourly  EXITSn_hourly  \
# count  131951.000000  131951.000000    131951.000000  131951.000000
# mean    65975.000000      10.896158      1095.348478     886.890838
# std     38091.117022       6.892084      2337.015421    2008.604886
# min         0.000000       0.000000         0.000000       0.000000
# 25%     32987.500000       5.000000        39.000000      32.000000
# 50%     65975.000000      12.000000       279.000000     232.000000
# 75%     98962.500000      17.000000      1109.000000     847.000000
# max    131950.000000      23.000000     51839.000000   45249.000000
#
#         maxpressurei      maxdewpti      mindewpti   minpressurei  \
# count  131951.000000  131951.000000  131951.000000  131951.000000
# mean       30.031894      57.241302      48.259013      29.892714
# std         0.125689       8.770891      11.305312       0.146384
# min        29.740000      39.000000      22.000000      29.540000
# ...

# %%
data
# Out:
#     Unnamed: 0  UNIT       DATEn     TIMEn  Hour    DESCn  ENTRIESn_hourly  \
# 0            0  R001  2011-05-01  01:00:00     1  REGULAR                0
# 1            1  R001  2011-05-01  05:00:00     5  REGULAR              217
# 2            2  R001  2011-05-01  09:00:00     9  REGULAR              890
# 3            3  R001  2011-05-01  13:00:00    13  REGULAR             2451
# 4            4  R001  2011-05-01  17:00:00    17  REGULAR             4400
# 5            5  R001  2011-05-01  21:00:00    21  REGULAR             3372
# 6            6  R002  2011-05-01  01:00:00     1  REGULAR                0
# 7            7  R002  2011-05-01  05:00:00     5  REGULAR               42
# 8            8  R002  2011-05-01  09:00:00     9  REGULAR               50
# 9            9  R002  2011-05-01  13:00:00    13  REGULAR              316
# 10          10  R002  2011-05-01  17:00:00    17  REGULAR              633
# ...

# %% [markdown]
# ## Simple Approach
# H0 is weather conditions have in influence on subway usuage, e.g. rain pushes the people in the subway. So the H1 is weather conditions have **no** influence on subway usage.

# %%
data.fog.value_counts()
# Out:
# 0    109902
# 1     22049
# dtype: int64

# %%
data.rain.value_counts()
# Out:
# 0    87847
# 1    44104
# dtype: int64

# %%
data.thunder.value_counts()
# Out:
# 0    131951
# dtype: int64

# %% [markdown]
# **Stop** No Thunder, we can skip this column

# %%
data.DESCn.value_counts()
# Out:
# REGULAR    131951
# dtype: int64

# %% [markdown]
# And again _no_ difference in the values, everytime _regular_ we can skip this too.

# %% [markdown]
# ## Breaking up the Matrix
# I create some subsets of data, rainy days and non rainy days and see how many passangers come in the subway. I say _rainy days_ it should better named rainy times, because we check timeframes with rain.

# %%
rainy_days = pd.DataFrame(data[data.rain == 1])

# %%
rainy_days2 = rainy_days[['ENTRIESn_hourly', 'EXITSn_hourly','DATEn']]

# %%
rainy_days2 = rainy_days2.set_index('DATEn')

# %%
rainy_days2.head(5)
# Out:
#             ENTRIESn_hourly  EXITSn_hourly
# DATEn
# 2011-05-04             1132           1840
# 2011-05-04              164            305
# 2011-05-04              647            425
# 2011-05-04             6468           6293
# 2011-05-04             4683           6226
#
# [5 rows x 2 columns]

# %%
rainy_days2.describe()
# Out:
#        ENTRIESn_hourly  EXITSn_hourly
# count     44104.000000   44104.000000
# mean       1105.446377     894.123572
# std        2370.527674    2028.552487
# min           0.000000       0.000000
# 25%          41.000000      33.000000
# 50%         282.000000     235.000000
# 75%        1103.250000     849.000000
# max       51839.000000   41503.000000
#
# [8 rows x 2 columns]

# %%
rainy_days2.plot(rot = 90)

# %%
non_rainy_days = pd.DataFrame(data[data.rain == 0])

# %%
non_rainy_days2 = non_rainy_days[['ENTRIESn_hourly', 'EXITSn_hourly', 'DATEn']]

# %%
non_rainy_days2 = non_rainy_days2.set_index('DATEn')

# %%
non_rainy_days2.describe()
# Out:
#        ENTRIESn_hourly  EXITSn_hourly
# count     87847.000000   87847.000000
# mean       1090.278780     883.259610
# std        2320.004938    1998.516762
# min           0.000000       0.000000
# 25%          38.000000      31.000000
# 50%         278.000000     231.000000
# 75%        1111.000000     846.000000
# max       43199.000000   45249.000000
#
# [8 rows x 2 columns]

# %%
non_rainy_days2.plot(rot = 90)

# %% [markdown]
# ## First Summray: Rain
# That looks like more people in the subway on rainy days. Or not?

# %%
data.ix[:, 'fog' : 'mintempi']
# Out:
#     fog  rain  meanwindspdi  mintempi
# 0     0     0             5        50
# 1     0     0             5        50
# 2     0     0             5        50
# 3     0     0             5        50
# 4     0     0             5        50
# 5     0     0             5        50
# 6     0     0             5        50
# 7     0     0             5        50
# 8     0     0             5        50
# 9     0     0             5        50
# 10    0     0             5        50
# 11    0     0             5        50
# 12    0     0             5        50
# 13    0     0             5        50
# 14    0     0             5        50
# 15    0     0             5        50
# 16    0     0             5        50
# 17    0     0             5        50
# 18    0     0             5        50
# 19    0     0             5        50
# 20    0     0             5        50
# 21    0     0             5        50
# 22    0     0             5        50
# 23    0     0             5        50
# ...
